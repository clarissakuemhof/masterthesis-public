# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### (1) Hyperparameter Sensitivity

# %%
df = pd.read_csv('hyperparameter-sensitivity-halfcheetah.csv')

steps = df["global_step"]
hypervolume_run1 = df["mo-halfcheetah-v4__EMOS_complexEA_selection_dynamic__3__1737063174 - eval/hypervolume"]
hypervolume_run2 = df["mo-halfcheetah-v4__EMOS_complexEA_selection_dynamic__3__1737043211 - eval/hypervolume"]
hypervolume_run3 = df["mo-halfcheetah-v4__EMOS_complexEA_selection_dynamic__3__1737003507 - eval/hypervolume"]

plt.figure(figsize=(6, 4))
#plt.plot(steps, hypervolume_run1, label="A: novelty = 0.9, recombination rate = 0.8", color='#DA4C4C')
#plt.plot(steps, hypervolume_run2, label="configuration B", color='#A12864')
#plt.plot(steps, hypervolume_run3, label="configuration C", color='#C565C7')

plt.plot(steps, hypervolume_run3, label="A: novelty = 0.9, recombination rate = 0.8", color='#C565C7')
plt.plot(steps, hypervolume_run1, label="B: novelty = 0.3, recombination rate = 0.8", color='#DA4C4C')
plt.plot(steps, hypervolume_run2, label="C: novelty = 0.3, recombination rate = 0.05", color='#A12864')

plt.xlabel("Training Steps", fontsize=16)
plt.ylabel("Hypervolume (↑)", fontsize=16)
# plt.title("Hypervolume Progression Across Steps", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle="--", linewidth=0.5)

plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/hyperparameter-sensitivity-halfcheetah.pdf", format="pdf", bbox_inches="tight")


# Show the plot
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('hyperparameter-sensitivity-hopper.csv')

steps = df["global_step"]
hypervolume_run1 = df["mo-hopper-2d-v4__EMOS_complexEA_selection_dynamic__4__1737019674 - eval/hypervolume"]
hypervolume_run2 = df["mo-hopper-2d-v4__EMOS_complexEA_selection_dynamic__4__1736981587 - eval/hypervolume"]
hypervolume_run3 = df["mo-hopper-2d-v4__EMOS_complexEA_selection_dynamic__4__1736948206 - eval/hypervolume"]

plt.figure(figsize=(6, 4))
plt.plot(steps, hypervolume_run1, label="A: novelty = 0.9, recombination rate = 0.8", color='#C565C7')
plt.plot(steps, hypervolume_run2, label="B: novelty = 0.3, recombination rate = 0.8", color='#DA4C4C')
plt.plot(steps, hypervolume_run3, label="C: novelty = 0.3, recombination rate = 0.05", color='#A12864')

plt.xlabel("Training Steps", fontsize=16)
plt.ylabel("Hypervolume (↑)", fontsize=16)
# plt.title("Hypervolume Progression Across Steps", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle="--", linewidth=0.5)

plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/hyperparameter-sensitivity-hopper.pdf", format="pdf", bbox_inches="tight")

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### (2a) Comparison intermediate version vs. final EMOS (halfcheetah)

# %% [markdown]
# ### (2b) Comparison intermediate version vs. final EMOS (hopper)

# %% [markdown]
# ### **(2c) Comparison intermediate version vs. final EMOS (both envs)**

# %%
df_eum_intermediate_hc = pd.read_csv('intermediate-EUM-halfcheetah.csv')
df_hv_intermediate_hc = pd.read_csv('intermediate-HV-halfcheetah.csv')
df_sparsity_intermediate_hc = pd.read_csv('intermediate-sparsity-halfcheetah.csv')

df_eum_intermediate_hopper = pd.read_csv('intermediate-EUM-hopper.csv')
df_hv_intermediate_hopper = pd.read_csv('intermediate-HV-hopper.csv')
df_sparsity_intermediate_hopper = pd.read_csv('intermediate-sparsity-hopper.csv')

df_eum_emos_hc = pd.read_csv('emos-EUM-halfcheetah.csv')
df_hv_emos_hc = pd.read_csv('emos-HV-halfcheetah.csv')
df_sparsity_emos_hc = pd.read_csv('emos-sparsity-halfcheetah.csv')

df_eum_emos_hopper = pd.read_csv('emos-EUM-hopper.csv')
df_hv_emos_hopper = pd.read_csv('emos-HV-hopper.csv')
df_sparsity_emos_hopper = pd.read_csv('emos-sparsity-hopper.csv')

df_eum_intermediate_hc["global_step"] = df_eum_intermediate_hc["global_step"] / 1_000_000

fig, axes = plt.subplots(3, 2, figsize=(13, 12), sharex=True)
plt.rcParams["font.size"] = 12

# Plot for HalfCheetah (Left Column)
axes[0, 0].plot(df_eum_intermediate_hc["global_step"], df_eum_intermediate_hc["algo: EMOS_NOcomplexEA_optimized - eval/eum"], label='EMOS (no complex EAs)', color='#9C7922')
axes[0, 0].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_eum_intermediate_hc["algo: EMOS_NOcomplexEA_optimized - eval/eum__MIN"], 
                        df_eum_intermediate_hc["algo: EMOS_NOcomplexEA_optimized - eval/eum__MAX"], 
                        color='#9C7922', alpha=0.1)
axes[0, 0].plot(df_eum_intermediate_hc["global_step"], df_eum_emos_hc["algo: EMOS - eval/eum"], label='EMOS', color='#EDB732')
axes[0, 0].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_eum_emos_hc["algo: EMOS - eval/eum__MIN"], 
                        df_eum_emos_hc["algo: EMOS - eval/eum__MAX"], 
                        color='#EDB732', alpha=0.1)
# axes[0, 0].set_title('mo-halfcheetah-v4')
axes[0, 0].set_ylabel('Expected Utility (↑)')
axes[0, 0].legend()
axes[0, 0].grid(True)

axes[1, 0].plot(df_eum_intermediate_hc["global_step"], df_hv_intermediate_hc["algo: EMOS_NOcomplexEA_optimized - eval/hypervolume"], color='#9C7922')
axes[1, 0].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_hv_intermediate_hc["algo: EMOS_NOcomplexEA_optimized - eval/hypervolume__MIN"], 
                        df_hv_intermediate_hc["algo: EMOS_NOcomplexEA_optimized - eval/hypervolume__MAX"], 
                        color='#9C7922', alpha=0.1)
axes[1, 0].plot(df_eum_intermediate_hc["global_step"], df_hv_emos_hc["algo: EMOS - eval/hypervolume"], color='#EDB732')
axes[1, 0].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_hv_emos_hc["algo: EMOS - eval/hypervolume__MIN"], 
                        df_hv_emos_hc["algo: EMOS - eval/hypervolume__MAX"], 
                        color='#EDB732', alpha=0.1)
# axes[1, 0].set_title('HalfCheetah - Hypervolume (↑)')
axes[1, 0].set_ylabel('Hypervolume (↑)')
axes[1, 0].grid(True)

axes[2, 0].plot(df_eum_intermediate_hc["global_step"], df_sparsity_intermediate_hc["algo: EMOS_NOcomplexEA_optimized - eval/sparsity"], color='#9C7922')
axes[2, 0].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_sparsity_intermediate_hc["algo: EMOS_NOcomplexEA_optimized - eval/sparsity__MIN"], 
                        df_sparsity_intermediate_hc["algo: EMOS_NOcomplexEA_optimized - eval/sparsity__MAX"], 
                        color='#9C7922', alpha=0.1)
axes[2, 0].plot(df_eum_intermediate_hc["global_step"], df_sparsity_emos_hc["algo: EMOS - eval/sparsity"], color='#EDB732')
axes[2, 0].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_sparsity_emos_hc["algo: EMOS - eval/sparsity__MIN"], 
                        df_sparsity_emos_hc["algo: EMOS - eval/sparsity__MAX"], 
                        color='#EDB732', alpha=0.1)
# axes[2, 0].set_title('HalfCheetah - Sparsity (↓)')
axes[2, 0].set_ylabel('Sparsity (↓)')
axes[2, 0].grid(True)

# Plot for Hopper (Right Column)
axes[0, 1].plot(df_eum_intermediate_hc["global_step"], df_eum_intermediate_hopper["algo: EMOS_NOcomplexEA_optimized - eval/eum"], color='#9C7922')
axes[0, 1].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_eum_intermediate_hopper["algo: EMOS_NOcomplexEA_optimized - eval/eum__MIN"], 
                        df_eum_intermediate_hopper["algo: EMOS_NOcomplexEA_optimized - eval/eum__MAX"], 
                        color='#9C7922', alpha=0.1)
axes[0, 1].plot(df_eum_intermediate_hc["global_step"], df_eum_emos_hopper["algo: EMOS - eval/eum"], color='#EDB732')
axes[0, 1].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_eum_emos_hopper["algo: EMOS - eval/eum__MIN"], 
                        df_eum_emos_hopper["algo: EMOS - eval/eum__MAX"], 
                        color='#EDB732', alpha=0.1)
#axes[0, 1].set_title('mo-hopper-2d-v4')
#axes[0, 1].set_ylabel('Expected Utility (↑)')
axes[0, 1].legend()

axes[0, 1].grid(True)

axes[1, 1].plot(df_eum_intermediate_hc["global_step"], df_hv_intermediate_hopper["algo: EMOS_NOcomplexEA_optimized - eval/hypervolume"], color='#9C7922')
axes[1, 1].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_hv_intermediate_hopper["algo: EMOS_NOcomplexEA_optimized - eval/hypervolume__MIN"], 
                        df_hv_intermediate_hopper["algo: EMOS_NOcomplexEA_optimized - eval/hypervolume__MAX"], 
                        color='#9C7922', alpha=0.1)
axes[1, 1].plot(df_eum_intermediate_hc["global_step"], df_hv_emos_hopper["algo: EMOS - eval/hypervolume"], color='#EDB732')
axes[1, 1].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_hv_emos_hopper["algo: EMOS - eval/hypervolume__MIN"], 
                        df_hv_emos_hopper["algo: EMOS - eval/hypervolume__MAX"], 
                        color='#EDB732', alpha=0.1)
# axes[1, 1].set_title('Hopper - Hypervolume (↑)')
#axes[1, 1].set_ylabel('Hypervolume (↑)')
axes[1, 1].grid(True)

axes[2, 1].plot(df_eum_intermediate_hc["global_step"], df_sparsity_intermediate_hopper["algo: EMOS_NOcomplexEA_optimized - eval/sparsity"], color='#9C7922')
axes[2, 1].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_sparsity_intermediate_hopper["algo: EMOS_NOcomplexEA_optimized - eval/sparsity__MIN"], 
                        df_sparsity_intermediate_hopper["algo: EMOS_NOcomplexEA_optimized - eval/sparsity__MAX"], 
                        color='#9C7922', alpha=0.1)
axes[2, 1].plot(df_eum_intermediate_hc["global_step"], df_sparsity_emos_hopper["algo: EMOS - eval/sparsity"], color='#EDB732')
axes[2, 1].fill_between(df_eum_intermediate_hc["global_step"], 
                        df_sparsity_emos_hopper["algo: EMOS - eval/sparsity__MIN"], 
                        df_sparsity_emos_hopper["algo: EMOS - eval/sparsity__MAX"], 
                        color='#EDB732', alpha=0.1)
# axes[2, 1].set_title('Hopper - Sparsity (↓)')
#axes[2, 1].set_ylabel('Sparsity (↓)')
axes[2, 1].grid(True)

for ax in axes.flat:
    # ax.set_xlabel("Training Steps (M)", fontdict={"fontsize": 16})
    ax.set_ylabel(ax.get_ylabel(), fontdict={"fontsize": 14})
    ax.legend(prop={"size": 14})  
    ax.grid(True)

for ax in axes[2, :]:
    ax.set_xlabel('Training Steps (M)', fontdict={"fontsize": 14})

axes[0, 0].set_title('mo-halfcheetah-v4', fontdict={"fontsize": 14})
axes[0, 1].set_title('mo-hopper-2d-v4', fontdict={"fontsize": 14})

plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/intermediate-both-envs.pdf", format="pdf", bbox_inches="tight")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/1093029321.py:79: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0, 1].legend()
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/1093029321.py:114: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(prop={"size": 14})

# %% [markdown]
# ### (3a) Comparison PGMORL vs. EMOS (halfcheetah)

# %% [markdown]
# because PGMORL is EMOS am ähnlichsten

# %%
df_eum_pgmorl = pd.read_csv('pgmorl-EUM-halfcheetah.csv')
df_eum_emos = pd.read_csv('emos-EUM-halfcheetah.csv')
df_hypervolume_pgmorl = pd.read_csv('pgmorl-HV-halfcheetah.csv')
df_hypervolume_emos = pd.read_csv('emos-HV-halfcheetah.csv')
df_sparsity_pgmorl = pd.read_csv('pgmorl-sparsity-halfcheetah.csv')
df_sparsity_emos = pd.read_csv('emos-sparsity-halfcheetah.csv')

for df in [df_eum_pgmorl,df_eum_emos,df_hypervolume_pgmorl,df_hypervolume_emos,df_sparsity_pgmorl,df_sparsity_emos]:
    df["global_step"] = df["global_step"] / 1_000_000

fig, axes = plt.subplots(1, 3, figsize=(18, 6))  

# EUM Plot (Left)
axes[0].plot(df_eum_pgmorl["global_step"], df_eum_pgmorl["algo: PGMORL - eval/eum"], color='#5BC5DB')
axes[0].fill_between(df_eum_pgmorl["global_step"], 
                     df_eum_pgmorl["algo: PGMORL - eval/eum__MIN"], 
                     df_eum_pgmorl["algo: PGMORL - eval/eum__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[0].plot(df_eum_emos["global_step"], df_eum_emos["algo: EMOS - eval/eum"], color='#EDB732')
axes[0].fill_between(df_eum_emos["global_step"], 
                     df_eum_emos["algo: EMOS - eval/eum__MIN"], 
                     df_eum_emos["algo: EMOS - eval/eum__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[0].set_title('Expected Utility (↑)', fontdict={"fontsize": 20})
axes[0].legend()
axes[0].grid(True)

# Hypervolume Plot (Middle)
axes[1].plot(df_hypervolume_pgmorl["global_step"], df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume"], color='#5BC5DB')
axes[1].fill_between(df_hypervolume_pgmorl["global_step"], 
                     df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume__MIN"], 
                     df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[1].plot(df_hypervolume_emos["global_step"], df_hypervolume_emos["algo: EMOS - eval/hypervolume"], color='#EDB732')
axes[1].fill_between(df_hypervolume_emos["global_step"], 
                     df_hypervolume_emos["algo: EMOS - eval/hypervolume__MIN"], 
                     df_hypervolume_emos["algo: EMOS - eval/hypervolume__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[1].set_title('Hypervolume (↑)', fontdict={"fontsize": 20})
axes[1].set_xlabel('Training Steps (M)', fontdict={"fontsize": 20})
axes[1].legend()
axes[1].grid(True)

# Sparsity Plot (Right)
axes[2].plot(df_sparsity_pgmorl["global_step"], df_sparsity_pgmorl["algo: PGMORL - eval/sparsity"], label='PGMORL', color='#5BC5DB')
axes[2].fill_between(df_sparsity_pgmorl["global_step"], 
                     df_sparsity_pgmorl["algo: PGMORL - eval/sparsity__MIN"], 
                     df_sparsity_pgmorl["algo: PGMORL - eval/sparsity__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[2].plot(df_sparsity_emos["global_step"], df_sparsity_emos["algo: EMOS - eval/sparsity"], label='EMOS', color='#EDB732')
axes[2].fill_between(df_sparsity_emos["global_step"], 
                     df_sparsity_emos["algo: EMOS - eval/sparsity__MIN"], 
                     df_sparsity_emos["algo: EMOS - eval/sparsity__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[2].set_title('Sparsity (↓)', fontdict={"fontsize": 20})
axes[2].legend()
axes[2].grid(True)

for ax in axes:
    #ax.set_xlim(0, 20)
    ax.set_xlabel(ax.get_xlabel(), fontdict={"fontsize": 20})
    ax.legend(prop={"size": 18})  
    ax.grid(True)

plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/pgmorl-emos-halfcheetah.pdf", format="pdf", bbox_inches="tight")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/2769332878.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend()
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/2769332878.py:45: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend()
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/2769332878.py:68: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(prop={"size": 18})

# %% [markdown]
# ### (3b) Comparison PGMORL vs. EMOS (hopper)

# %%
df_eum_pgmorl = pd.read_csv('pgmorl-EUM-hopper.csv')
df_eum_emos = pd.read_csv('emos-EUM-hopper.csv')
df_hypervolume_pgmorl = pd.read_csv('pgmorl-HV-hopper.csv')
df_hypervolume_emos = pd.read_csv('emos-HV-hopper.csv')
df_sparsity_pgmorl = pd.read_csv('pgmorl-sparsity-hopper.csv')
df_sparsity_emos = pd.read_csv('emos-sparsity-hopper.csv')

for df in [df_eum_pgmorl,df_eum_emos,df_hypervolume_pgmorl,df_hypervolume_emos,df_sparsity_pgmorl,df_sparsity_emos]:
    df["global_step"] = df["global_step"] / 1_000_000

fig, axes = plt.subplots(1, 3, figsize=(18, 6))  

# EUM Plot (Left)
axes[0].plot(df_eum_pgmorl["global_step"], df_eum_pgmorl["algo: PGMORL - eval/eum"], color='#5BC5DB')
axes[0].fill_between(df_eum_pgmorl["global_step"], 
                     df_eum_pgmorl["algo: PGMORL - eval/eum__MIN"], 
                     df_eum_pgmorl["algo: PGMORL - eval/eum__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[0].plot(df_eum_emos["global_step"], df_eum_emos["algo: EMOS - eval/eum"], color='#EDB732')
axes[0].fill_between(df_eum_emos["global_step"], 
                     df_eum_emos["algo: EMOS - eval/eum__MIN"], 
                     df_eum_emos["algo: EMOS - eval/eum__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[0].set_title('Expected Utility (↑)', fontdict={"fontsize": 20})
axes[0].legend()
axes[0].grid(True)

# Hypervolume Plot (Middle)
axes[1].plot(df_hypervolume_pgmorl["global_step"], df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume"], color='#5BC5DB')
axes[1].fill_between(df_hypervolume_pgmorl["global_step"], 
                     df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume__MIN"], 
                     df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[1].plot(df_hypervolume_emos["global_step"], df_hypervolume_emos["algo: EMOS - eval/hypervolume"], color='#EDB732')
axes[1].fill_between(df_hypervolume_emos["global_step"], 
                     df_hypervolume_emos["algo: EMOS - eval/hypervolume__MIN"], 
                     df_hypervolume_emos["algo: EMOS - eval/hypervolume__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[1].set_title('Hypervolume (↑)', fontdict={"fontsize": 20})
axes[1].set_xlabel('Training Steps (M)', fontdict={"fontsize": 20})
axes[1].legend()
axes[1].grid(True)

# Sparsity Plot (Right)
axes[2].plot(df_sparsity_pgmorl["global_step"], df_sparsity_pgmorl["algo: PGMORL - eval/sparsity"], label='PGMORL', color='#5BC5DB')
axes[2].fill_between(df_sparsity_pgmorl["global_step"], 
                     df_sparsity_pgmorl["algo: PGMORL - eval/sparsity__MIN"], 
                     df_sparsity_pgmorl["algo: PGMORL - eval/sparsity__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[2].plot(df_sparsity_emos["global_step"], df_sparsity_emos["algo: EMOS - eval/sparsity"], label='EMOS', color='#EDB732')
axes[2].fill_between(df_sparsity_emos["global_step"], 
                     df_sparsity_emos["algo: EMOS - eval/sparsity__MIN"], 
                     df_sparsity_emos["algo: EMOS - eval/sparsity__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[2].set_title('Sparsity (↓)', fontdict={"fontsize": 20})
axes[2].legend()
axes[2].grid(True)

for ax in axes:
    #ax.set_xlim(0, 20)
    ax.set_xlabel(ax.get_xlabel(), fontdict={"fontsize": 20})
    ax.legend(prop={"size": 18})  
    ax.grid(True)

plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/pgmorl-emos-hopper.pdf", format="pdf", bbox_inches="tight")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/2579274861.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend()
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/2579274861.py:45: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend()
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/2579274861.py:68: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(prop={"size": 18})

# %% [markdown]
# ### (4a) Comparison EMOS vs. PGMORL/CAPQL/GPI (halfcheetah)

# %%
df_eum_pgmorl = pd.read_csv('pgmorl-EUM-halfcheetah.csv')
df_eum_emos = pd.read_csv('emos-EUM-halfcheetah.csv')
df_eum_capql = pd.read_csv('capql-EUM-halfcheetah.csv')

df_hypervolume_pgmorl = pd.read_csv('pgmorl-HV-halfcheetah.csv')
df_hypervolume_emos = pd.read_csv('emos-HV-halfcheetah.csv')
df_hypervolume_capql = pd.read_csv('capql-HV-halfcheetah.csv')

df_sparsity_pgmorl = pd.read_csv('pgmorl-sparsity-halfcheetah.csv')
df_sparsity_emos = pd.read_csv('emos-sparsity-halfcheetah.csv')
df_sparsity_capql = pd.read_csv('capql-sparsity-halfcheetah.csv')

for df in [df_eum_pgmorl,df_eum_emos,df_eum_capql,df_hypervolume_pgmorl,df_hypervolume_emos,df_hypervolume_capql,df_sparsity_pgmorl,df_sparsity_emos,df_sparsity_capql]:
    df["global_step"] = df["global_step"] / 1_000_000

# GPI's max value for each metric as a dashed line in halfcheetah
# same seeds as other algs -> min/max from there

eum_gpi = 296
eum_gpi_MIN = 224
eum_gpi_MAX = 350
hypervolume_gpi = 55152
hypervolume_gpi_MIN = 45708
hypervolume_gpi_MAX = 61033
sparsity_gpi = 17406
sparsity_gpi_MIN = 6313
sparsity_gpi_MAX = 26274

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# EUM Plot (Left)
axes[0].plot(df_eum_pgmorl["global_step"], df_eum_pgmorl["algo: PGMORL - eval/eum"], color='#5BC5DB')
axes[0].fill_between(df_eum_pgmorl["global_step"], 
                     df_eum_pgmorl["algo: PGMORL - eval/eum__MIN"], 
                     df_eum_pgmorl["algo: PGMORL - eval/eum__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[0].plot(df_eum_emos["global_step"], df_eum_emos["algo: EMOS - eval/eum"], color='#EDB732')
axes[0].fill_between(df_eum_emos["global_step"], 
                     df_eum_emos["algo: EMOS - eval/eum__MIN"], 
                     df_eum_emos["algo: EMOS - eval/eum__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[0].plot(df_eum_capql["global_step"], df_eum_capql["algo: CAPQL - eval/eum"], color='#E57439')
axes[0].fill_between(df_eum_capql["global_step"], 
                     df_eum_capql["algo: CAPQL - eval/eum__MIN"], 
                     df_eum_capql["algo: CAPQL - eval/eum__MAX"], 
                     color='#E57439', alpha=0.1)

# Dashed line for GPI's max value
axes[0].axhline(y=eum_gpi, color='#229487', linestyle='--')
axes[0].fill_between(df_eum_pgmorl["global_step"], eum_gpi_MIN, eum_gpi_MAX, color="#229487", alpha=0.1)

axes[0].set_title('Expected Utility (↑)', fontdict={"fontsize": 20})
axes[0].legend()
axes[0].grid(True)

# Hypervolume Plot (Middle)
axes[1].plot(df_hypervolume_pgmorl["global_step"], df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume"], color='#5BC5DB')
axes[1].fill_between(df_hypervolume_pgmorl["global_step"], 
                     df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume__MIN"], 
                     df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[1].plot(df_hypervolume_emos["global_step"], df_hypervolume_emos["algo: EMOS - eval/hypervolume"], color='#EDB732')
axes[1].fill_between(df_hypervolume_emos["global_step"], 
                     df_hypervolume_emos["algo: EMOS - eval/hypervolume__MIN"], 
                     df_hypervolume_emos["algo: EMOS - eval/hypervolume__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[1].plot(df_hypervolume_capql["global_step"], df_hypervolume_capql["algo: CAPQL - eval/hypervolume"], color='#E57439')
axes[1].fill_between(df_hypervolume_capql["global_step"], 
                     df_hypervolume_capql["algo: CAPQL - eval/hypervolume__MIN"], 
                     df_hypervolume_capql["algo: CAPQL - eval/hypervolume__MAX"], 
                     color='#E57439', alpha=0.1)

# Dashed line for GPI's max value
axes[1].axhline(y=hypervolume_gpi, color='#229487', linestyle='--')
axes[1].fill_between(df_eum_pgmorl["global_step"], hypervolume_gpi_MIN, hypervolume_gpi_MAX, color="#229487", alpha=0.1)

axes[1].set_title('Hypervolume (↑)', fontdict={"fontsize": 20})
axes[1].set_xlabel('Training Steps (M)', fontdict={"fontsize": 20})
axes[1].legend()
axes[1].grid(True)

# Sparsity Plot (Right)
axes[2].plot(df_sparsity_pgmorl["global_step"], df_sparsity_pgmorl["algo: PGMORL - eval/sparsity"], label='PGMORL', color='#5BC5DB')
axes[2].fill_between(df_sparsity_pgmorl["global_step"], 
                     df_sparsity_pgmorl["algo: PGMORL - eval/sparsity__MIN"], 
                     df_sparsity_pgmorl["algo: PGMORL - eval/sparsity__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[2].plot(df_sparsity_emos["global_step"], df_sparsity_emos["algo: EMOS - eval/sparsity"], label='EMOS', color='#EDB732')
axes[2].fill_between(df_sparsity_emos["global_step"], 
                     df_sparsity_emos["algo: EMOS - eval/sparsity__MIN"], 
                     df_sparsity_emos["algo: EMOS - eval/sparsity__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[2].plot(df_sparsity_capql["global_step"], df_sparsity_capql["algo: CAPQL - eval/sparsity"], label='CAPQL', color='#E57439')
axes[2].fill_between(df_sparsity_capql["global_step"], 
                     df_sparsity_capql["algo: CAPQL - eval/sparsity__MIN"], 
                     df_sparsity_capql["algo: CAPQL - eval/sparsity__MAX"], 
                     color='#E57439', alpha=0.1)

# Dashed line for GPI's max value
axes[2].axhline(y=sparsity_gpi, color='#229487', linestyle='--', label='GPI')
axes[2].fill_between(df_eum_pgmorl["global_step"], sparsity_gpi_MIN, sparsity_gpi_MAX, color="#229487", alpha=0.1)

axes[2].set_title('Sparsity (↓)', fontdict={"fontsize": 20})
axes[2].legend()
axes[2].grid(True)

for ax in axes:
    ax.set_xlim(0, 5)
    ax.set_xlabel(ax.get_xlabel(), fontdict={"fontsize": 20})
    ax.legend(prop={"size": 18})  
    ax.grid(True)

plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/pgmorl-emos-capql-gpi-halfcheetah-5.pdf", format="pdf", bbox_inches="tight")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/183661729.py:55: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend()
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/183661729.py:83: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend()
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/183661729.py:116: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(prop={"size": 18})

# %% [markdown]
# ### (4b) Comparison EMOS vs. PGMORL/CAPQL/GPI (hopper)

# %%
df_eum_pgmorl = pd.read_csv('pgmorl-EUM-hopper.csv')
df_eum_emos = pd.read_csv('emos-EUM-hopper.csv')
df_eum_capql = pd.read_csv('capql-EUM-hopper.csv')

df_hypervolume_pgmorl = pd.read_csv('pgmorl-HV-hopper.csv')
df_hypervolume_emos = pd.read_csv('emos-HV-hopper.csv')
df_hypervolume_capql = pd.read_csv('capql-HV-hopper.csv')

df_sparsity_pgmorl = pd.read_csv('pgmorl-sparsity-hopper.csv')
df_sparsity_emos = pd.read_csv('emos-sparsity-hopper.csv')
df_sparsity_capql = pd.read_csv('capql-sparsity-hopper.csv')

for df in [df_eum_pgmorl,df_eum_emos,df_eum_capql,df_hypervolume_pgmorl,df_hypervolume_emos,df_hypervolume_capql,df_sparsity_pgmorl,df_sparsity_emos,df_sparsity_capql]:
    df["global_step"] = df["global_step"] / 1_000_000

# GPI's max value for each metric as a dashed line in hopper
eum_gpi = 220
hypervolume_gpi = 108669
sparsity_gpi = 58
eum_gpi_MIN = 212
eum_gpi_MAX = 227
hypervolume_gpi_MIN = 102010
hypervolume_gpi_MAX = 113679
sparsity_gpi_MIN = 21
sparsity_gpi_MAX = 114

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# EUM Plot (Left)
axes[0].plot(df_eum_pgmorl["global_step"], df_eum_pgmorl["algo: PGMORL - eval/eum"], color='#5BC5DB')
axes[0].fill_between(df_eum_pgmorl["global_step"], 
                     df_eum_pgmorl["algo: PGMORL - eval/eum__MIN"], 
                     df_eum_pgmorl["algo: PGMORL - eval/eum__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[0].plot(df_eum_emos["global_step"], df_eum_emos["algo: EMOS - eval/eum"], color='#EDB732')
axes[0].fill_between(df_eum_emos["global_step"], 
                     df_eum_emos["algo: EMOS - eval/eum__MIN"], 
                     df_eum_emos["algo: EMOS - eval/eum__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[0].plot(df_eum_capql["global_step"], df_eum_capql["algo: CAPQL - eval/eum"], color='#E57439')
axes[0].fill_between(df_eum_capql["global_step"], 
                     df_eum_capql["algo: CAPQL - eval/eum__MIN"], 
                     df_eum_capql["algo: CAPQL - eval/eum__MAX"], 
                     color='#E57439', alpha=0.1)

# Dashed line for GPI's max value
axes[0].axhline(y=eum_gpi, color='#229487', linestyle='--')
axes[0].fill_between(df_eum_pgmorl["global_step"], eum_gpi_MIN, eum_gpi_MAX, color="#229487", alpha=0.1)

axes[0].set_title('Expected Utility (↑)', fontdict={"fontsize": 20})
axes[0].legend()
axes[0].grid(True)

# Hypervolume Plot (Middle)
axes[1].plot(df_hypervolume_pgmorl["global_step"], df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume"], color='#5BC5DB')
axes[1].fill_between(df_hypervolume_pgmorl["global_step"], 
                     df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume__MIN"], 
                     df_hypervolume_pgmorl["algo: PGMORL - eval/hypervolume__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[1].plot(df_hypervolume_emos["global_step"], df_hypervolume_emos["algo: EMOS - eval/hypervolume"], color='#EDB732')
axes[1].fill_between(df_hypervolume_emos["global_step"], 
                     df_hypervolume_emos["algo: EMOS - eval/hypervolume__MIN"], 
                     df_hypervolume_emos["algo: EMOS - eval/hypervolume__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[1].plot(df_hypervolume_capql["global_step"], df_hypervolume_capql["algo: CAPQL - eval/hypervolume"], color='#E57439')
axes[1].fill_between(df_hypervolume_capql["global_step"], 
                     df_hypervolume_capql["algo: CAPQL - eval/hypervolume__MIN"], 
                     df_hypervolume_capql["algo: CAPQL - eval/hypervolume__MAX"], 
                     color='#E57439', alpha=0.1)

# Dashed line for GPI's max value
axes[1].axhline(y=hypervolume_gpi, color='#229487', linestyle='--')
axes[1].fill_between(df_eum_pgmorl["global_step"], hypervolume_gpi_MIN, hypervolume_gpi_MAX, color="#229487", alpha=0.1)

axes[1].set_title('Hypervolume (↑)', fontdict={"fontsize": 20})
axes[1].set_xlabel('Training Steps (M)', fontdict={"fontsize": 20})
axes[1].legend()
axes[1].grid(True)

# Sparsity Plot (Right)
axes[2].plot(df_sparsity_pgmorl["global_step"], df_sparsity_pgmorl["algo: PGMORL - eval/sparsity"], label='PGMORL', color='#5BC5DB')
axes[2].fill_between(df_sparsity_pgmorl["global_step"], 
                     df_sparsity_pgmorl["algo: PGMORL - eval/sparsity__MIN"], 
                     df_sparsity_pgmorl["algo: PGMORL - eval/sparsity__MAX"], 
                     color='#5BC5DB', alpha=0.1)

axes[2].plot(df_sparsity_emos["global_step"], df_sparsity_emos["algo: EMOS - eval/sparsity"], label='EMOS', color='#EDB732')
axes[2].fill_between(df_sparsity_emos["global_step"], 
                     df_sparsity_emos["algo: EMOS - eval/sparsity__MIN"], 
                     df_sparsity_emos["algo: EMOS - eval/sparsity__MAX"], 
                     color='#EDB732', alpha=0.1)

axes[2].plot(df_sparsity_capql["global_step"], df_sparsity_capql["algo: CAPQL - eval/sparsity"], label='CAPQL', color='#E57439')
axes[2].fill_between(df_sparsity_capql["global_step"], 
                     df_sparsity_capql["algo: CAPQL - eval/sparsity__MIN"], 
                     df_sparsity_capql["algo: CAPQL - eval/sparsity__MAX"], 
                     color='#E57439', alpha=0.1)

# Dashed line for GPI's max value
axes[2].axhline(y=sparsity_gpi, color='#229487', linestyle='--', label='GPI')
axes[2].fill_between(df_eum_pgmorl["global_step"], sparsity_gpi_MIN, sparsity_gpi_MAX, color="#229487", alpha=0.1)

axes[2].set_title('Sparsity (↓)', fontdict={"fontsize": 20})
axes[2].legend()
axes[2].grid(True)

for ax in axes:
    ax.set_xlim(0, 5)
    ax.set_xlabel(ax.get_xlabel(), fontdict={"fontsize": 20})
    ax.legend(prop={"size": 18})  
    ax.grid(True)

plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/pgmorl-emos-capql-gpi-hopper-5.pdf", format="pdf", bbox_inches="tight")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/481918614.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend()
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/481918614.py:81: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend()
# /var/folders/8b/1r42p3g57tb_w83ks_5pkrtw0000gn/T/ipykernel_8150/481918614.py:114: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(prop={"size": 18})

# %% [markdown]
# ### (5) Limitation of Quality of PF based on Hypervolume

# %%
df = pd.read_csv('hv-pf.csv')

steps = df["global_step"] / 1_000_000

hypervolume_high = df["mo-hopper-2d-v4__EMOS__2__1738007415 - eval/hypervolume"]
hypervolume_low = df["mo-hopper-2d-v4__EMOS__6__1737970516 - eval/hypervolume"]

plt.figure(figsize=(6, 4))
plt.plot(steps, hypervolume_high, label="Run A", color='#A12864')
plt.plot(steps, hypervolume_low, label="Run B", color='#C565C7')

plt.xlabel("Training Steps (M)", fontsize=12)
plt.ylabel("Hypervolume (↑)", fontsize=12)
# plt.title("Hypervolume Progression Across Steps", fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, linestyle="--", linewidth=0.5)

plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/limitation-pf-hv.pdf", format="pdf", bbox_inches="tight")

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### (6) Pareto fronts

# %%
# pareto front points
pf_pgmorl_hopper = [
    [
      217.87838745117188,
      -1.1101970672607422
    ],
    [
      201.12957763671875,
      132.61715698242188
    ],
    [
      118.48486328125,
      145.1537322998047
    ],
    [
      217.082763671875,
      47.80587387084961
    ],
    [
      202.44955444335938,
      116.23712158203125
    ]
  ]
pf_pgmorl_hc = [
    [
      1.52718985080719,
      -0.4437325596809387
    ],
    [
      3.7736995220184326,
      -0.5573540925979614
    ],
    [
      66.49244689941406,
      -1.4464904069900513
    ],
    [
      1.4940766096115112,
      -0.3642377257347107
    ],
    [
      98.17876434326172,
      -2.14544677734375
    ],
    [
      102.17454528808594,
      -2.3242573738098145
    ],
    [
      109.1231918334961,
      -2.425764799118042
    ],
    [
      110.51688385009766,
      -2.8785901069641113
    ],
    [
      77.35960388183594,
      -1.5521003007888794
    ],
    [
      43.63121795654297,
      -1.189494013786316
    ],
    [
      95.26368713378906,
      -1.8734683990478516
    ],
    [
      75.8637924194336,
      -1.4809935092926025
    ],
    [
      40.24150848388672,
      -0.9674338102340698
    ],
    [
      19.973114013671875,
      -0.7565004825592041
    ],
    [
      54.5799674987793,
      -1.2397691011428833
    ],
    [
      124.90928649902344,
      -3.30400013923645
    ],
    [
      137.574462890625,
      -3.9478821754455566
    ],
    [
      122.02191162109375,
      -3.110583782196045
    ],
    [
      0.2632741332054138,
      -0.10516061633825302
    ],
    [
      63.03693771362305,
      -1.249690294265747
    ],
    [
      0.09973607957363129,
      -0.08778144419193268
    ],
    [
      80.28256225585938,
      -1.7672256231307983
    ],
    [
      39.46954345703125,
      -0.9593416452407837
    ]
]

pf_emos_hopper = [
    [
      72.19378662109375,
      48.806827545166016
    ],
    [
      84.04954528808594,
      33.834228515625
    ],
    [
      80.70196533203125,
      34.2863655090332
    ],
    [
      75.2704849243164,
      35.741851806640625
    ],
    [
      94.56755065917969,
      29.232763290405273
    ],
    [
      93.13700866699219,
      29.739099502563477
    ],
    [
      97.19297790527344,
      26.002527236938477
    ],
    [
      108.55085754394531,
      17.28946876525879
    ],
    [
      130.27078247070312,
      1.7891639471054077
    ],
    [
      79.82271575927734,
      35.5115852355957
    ],
    [
      124.8385238647461,
      4.166058540344238
    ],
    [
      108.94425201416016,
      16.4487247467041
    ],
    [
      113.20057678222656,
      10.171688079833984
    ],
    [
      136.36398315429688,
      -6.3802571296691895
    ],
    [
      125.36585998535156,
      2.8951923847198486
    ],
    [
      130.5175018310547,
      0.6756690740585327
    ],
    [
      113.09344482421875,
      12.665543556213379
    ],
    [
      102.1444320678711,
      24.04286766052246
    ],
    [
      132.89645385742188,
      -2.4556751251220703
    ],
    [
      135.1433868408203,
      -2.783869504928589
    ],
    [
      149.51353454589844,
      -17.916095733642578
    ],
    [
      120.3497314453125,
      9.25958251953125
    ],
    [
      132.3506317138672,
      -2.388075113296509
    ],
    [
      148.0359344482422,
      -17.535581588745117
    ],
    [
      156.10165405273438,
      -23.664653778076172
    ],
    [
      146.91268920898438,
      -16.394453048706055
    ],
    [
      141.6825714111328,
      -11.631390571594238
    ],
    [
      151.6398468017578,
      -19.336191177368164
    ],
    [
      156.4766845703125,
      -24.823471069335938
    ],
    [
      155.849365234375,
      -20.678796768188477
    ],
    [
      158.77394104003906,
      -25.039304733276367
    ],
    [
      145.02699279785156,
      -11.824857711791992
    ],
    [
      167.8491668701172,
      -31.993017196655273
    ],
    [
      162.79751586914062,
      -28.0689697265625
    ],
    [
      167.65760803222656,
      -30.061260223388672
    ],
    [
      169.41346740722656,
      -34.57237243652344
    ],
    [
      140.50473022460938,
      -9.96041488647461
    ],
    [
      139.1266326904297,
      -8.046073913574219
    ]
  ]
pf_emos_hc = [
    [
      -0.5603749752044678,
      -0.6459206342697144
    ],
    [
      77.06230163574219,
      -4.566917419433594
    ],
    [
      69.36860656738281,
      -4.209845542907715
    ],
    [
      81.74957275390625,
      -4.667957305908203
    ],
    [
      80.05850982666016,
      -4.616661548614502
    ],
    [
      71.999755859375,
      -4.2872514724731445
    ],
    [
      87.42462158203125,
      -4.736584186553955
    ],
    [
      80.16659545898438,
      -4.655194282531738
    ],
    [
      82.08317565917969,
      -4.700156211853027
    ],
    [
      94.83367156982422,
      -4.786726951599121
    ],
    [
      110.22900390625,
      -5.290638446807861
    ],
    [
      102.28468322753906,
      -5.161182880401611
    ],
    [
      106.94886779785156,
      -5.288717746734619
    ],
    [
      89.57293701171875,
      -4.738697052001953
    ],
    [
      101.44374084472656,
      -5.002581596374512
    ],
    [
      98.50245666503906,
      -4.979613780975342
    ]
  ]

pf_capql_hopper = [
    [
      161.74975859871483,
      283.5505789896659
    ],
    [
      163.08727803839793,
      281.5118002783289
    ],
    [
      165.7515514990235,
      281.4753485044421
    ],
    [
      167.13269031816452,
      280.37578164028236
    ],
    [
      167.66813046966416,
      279.9073401278671
    ],
    [
      169.57646907841553,
      279.0222372001619
    ],
    [
      170.30948669687933,
      277.0877012751404
    ],
    [
      171.27886330142502,
      274.84165169028984
    ],
    [
      172.0319252679823,
      274.22222424697065
    ],
    [
      174.17171761982027,
      273.3783731956217
    ],
    [
      175.6875200086055,
      267.3114690006623
    ],
    [
      177.3208207593212,
      264.503435465644
    ],
    [
      180.21932847314602,
      263.1902940319178
    ],
    [
      182.97194512675196,
      260.55074623628536
    ],
    [
      183.83136551775388,
      257.59169370054224
    ],
    [
      184.31766847072578,
      255.56600761364462
    ],
    [
      184.44390542453476,
      253.55269648849062
    ],
    [
      186.2238870895206,
      253.51640198514542
    ],
    [
      187.49786484685902,
      252.4228399247586
    ],
    [
      189.14903347351938,
      251.31427606309444
    ],
    [
      189.80930031367316,
      249.94781847013655
    ],
    [
      190.6551861078493,
      248.81191628712259
    ],
    [
      191.33977096789604,
      246.37897935498185
    ],
    [
      192.05092291384062,
      243.58059263865871
    ],
    [
      192.07183745955552,
      243.39142802508724
    ],
    [
      193.37006897816318,
      240.36437724977804
    ],
    [
      194.66483940458275,
      237.69924945906897
    ],
    [
      194.792781000337,
      236.47165466419756
    ],
    [
      196.1321476979734,
      235.97106066055932
    ],
    [
      197.2756830846629,
      234.1380725455121
    ],
    [
      197.84968667878712,
      233.93779907518038
    ],
    [
      198.53479274617422,
      233.22227477574634
    ],
    [
      198.59606100483796,
      232.62666002103578
    ],
    [
      199.53575065011682,
      232.11205376747165
    ],
    [
      200.411993806962,
      231.6683479006544
    ],
    [
      201.37845022445254,
      229.34006527366873
    ],
    [
      201.5279718055448,
      227.06550096636965
    ],
    [
      202.11665578512185,
      226.33606658430236
    ],
    [
      203.22300342722738,
      225.41522328860955
    ],
    [
      204.12348874820455,
      224.34632871380728
    ],
    [
      204.60397573201772,
      222.39880618915612
    ],
    [
      205.2893333488493,
      219.4329096254387
    ],
    [
      205.1714520310983,
      221.47691744067075
    ],
    [
      206.18376417267137,
      218.81770774111618
    ],
    [
      206.562959283893,
      218.39305129306294
    ],
    [
      207.1751643500902,
      212.8567542205526
    ]
]
pf_capql_hc = [
    [
      597.0481503877488,
      -30.25799408674343
    ],
    [
      575.3097361733063,
      -30.052472745247996
    ],
    [
      677.173547890934,
      -31.845175463823715
    ],
    [
      715.1530105552781,
      -32.390729487709905
    ],
    [
      754.4130273794232,
      -32.98316636762047
    ],
    [
      725.6282942596654,
      -32.95248088865246
    ],
    [
      764.7421524535399,
      -33.0327461124546
    ],
    [
      634.863270621709,
      -30.591458102490197
    ],
    [
      847.5498844795744,
      -34.049331499186884
    ],
    [
      835.1802566513885,
      -33.731092853062364
    ],
    [
      851.3709642579895,
      -34.06485481792261
    ],
    [
      857.3212408230611,
      -35.12914753932655
    ],
    [
      860.6995918282075,
      -35.21978839280219
    ],
    [
      864.3687668787782,
      -35.89637211488771
    ],
    [
      869.2995207499247,
      -36.61845653118307
    ],
    [
      871.8565211959765,
      -36.96299265443231
    ],
    [
      876.2884184750728,
      -37.78869091042088
    ],
    [
      880.252870760276,
      -38.42545926074799
    ]
  ]

pf_gpi_hopper = [
    [
      237.20445389827364,
      193.63742213726948
    ],
    [
      235.05455366137613,
      208.29624485197255
    ],
    [
      232.75255295885435,
      212.42043432883838
    ],
    [
      234.07306584307807,
      210.74230176057463
    ],
    [
      232.9331198660133,
      212.28104602009762
    ],
    [
      253.83002956106793,
      177.78327656696055
    ],
    [
      254.5978102770896,
      173.34344045086283
    ],
    [
      255.29551280969318,
      168.93157533129315
    ]
  ]
pf_gpi_hc = [
    [
      28.05244144985363,
      -14.830040489205931
    ],
    [
      609.5261355900963,
      -28.459194216189008
    ],
    [
      659.0974040148897,
      -30.271915234360403
    ],
    [
      674.948258749928,
      -31.136603140897705
    ],
    [
      685.9677607310703,
      -31.783142124555617
    ],
    [
      698.8778490970726,
      -32.85873676385495
    ],
    [
      702.9841706833046,
      -33.08180836008241
    ],
    [
      710.7794116021483,
      -33.96015907636111
    ],
    [
      705.8542470282991,
      -33.82556102703029
    ],
    [
      711.6559955593141,
      -34.433972501827704
    ],
    [
      722.9875019525177,
      -34.74877456881859
    ],
    [
      732.4366821453848,
      -34.93872868794406
    ],
    [
      734.9415540816437,
      -36.30934406425054
    ],
    [
      734.1353276613925,
      -35.85560481774146
    ]
  ]

# %%
# x and y lists
pf_pgmorl_hopper_x, pf_pgmorl_hopper_y = zip(*pf_pgmorl_hopper)
pf_pgmorl_hc_x, pf_pgmorl_hc_y = zip(*pf_pgmorl_hc)

pf_emos_hopper_x, pf_emos_hopper_y = zip(*pf_emos_hopper)
pf_emos_hc_x, pf_emos_hc_y = zip(*pf_emos_hc)

pf_capql_hopper_x, pf_capql_hopper_y = zip(*pf_capql_hopper)
pf_capql_hc_x, pf_capql_hc_y = zip(*pf_capql_hc)

pf_gpi_hopper_x, pf_gpi_hopper_y = zip(*pf_gpi_hopper)
pf_gpi_hc_x, pf_gpi_hc_y = zip(*pf_gpi_hc)

colors = {
    "pgmorl": "#5BC5DB",
    "emos": "#EDB732",
    "capql": "#E57439",
    "gpi": "#229487"
}

# (pf-hopper.pdf)
plt.figure(figsize=(8, 6))
plt.scatter(pf_pgmorl_hopper_x, pf_pgmorl_hopper_y, label="PGMORL", color=colors["pgmorl"], marker='o', s=60)
plt.scatter(pf_emos_hopper_x, pf_emos_hopper_y, label="EMOS", color=colors["emos"], marker='o', s=60)
plt.scatter(pf_capql_hopper_x, pf_capql_hopper_y, label="CAPQL", color=colors["capql"], marker='o', s=60)
plt.scatter(pf_gpi_hopper_x, pf_gpi_hopper_y, label="GPI", color=colors["gpi"], marker='o', s=60)

plt.xlabel("Objective 1", fontdict={"fontsize": 22})
plt.ylabel("Objective 2", fontdict={"fontsize": 22})
# plt.title("Pareto Front - Hopper")
plt.legend(prop={"size": 17})
plt.grid(True)
plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/pf-hopper.pdf", format="pdf", bbox_inches="tight")
plt.close()

# (pf-halfcheetah.pdf)
plt.figure(figsize=(8, 6))
plt.scatter(pf_pgmorl_hc_x, pf_pgmorl_hc_y, label="PGMORL", color=colors["pgmorl"], marker='o', s=60)
plt.scatter(pf_emos_hc_x, pf_emos_hc_y, label="EMOS", color=colors["emos"], marker='o', s=60)
plt.scatter(pf_capql_hc_x, pf_capql_hc_y, label="CAPQL", color=colors["capql"], marker='o', s=60)
plt.scatter(pf_gpi_hc_x, pf_gpi_hc_y, label="GPI", color=colors["gpi"], marker='o', s=60)

plt.xlabel("Objective 1", fontdict={"fontsize": 22})
plt.ylabel("Objective 2", fontdict={"fontsize": 22})
# plt.title("Pareto Front - Half Cheetah")
plt.legend(prop={"size": 17})
plt.grid(True)
plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/pf-halfcheetah.pdf", format="pdf", bbox_inches="tight")
plt.close()

# (pf-emos-hopper.pdf)
plt.figure(figsize=(8, 6))
plt.scatter(pf_emos_hopper_x, pf_emos_hopper_y, label="EMOS", color=colors["emos"], marker='o', s=60)

plt.xlabel("Objective 1", fontdict={"fontsize": 22})
plt.ylabel("Objective 2", fontdict={"fontsize": 22})
# plt.title("Pareto Front - EMOS (Hopper)")
plt.legend(prop={"size": 17})
plt.grid(True)
plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/pf-emos-hopper.pdf", format="pdf", bbox_inches="tight")
plt.close()

# (pf-emos-halfcheetah.pdf)
plt.figure(figsize=(8, 6))
plt.scatter(pf_emos_hc_x, pf_emos_hc_y, label="EMOS", color=colors["emos"], marker='o', s=60)

plt.xlabel("Objective 1", fontdict={"fontsize": 22})
plt.ylabel("Objective 2", fontdict={"fontsize": 22})
# plt.title("Pareto Front - EMOS (Half Cheetah)")
plt.legend(prop={"size": 17})
plt.grid(True)
plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/pf-emos-halfcheetah.pdf", format="pdf", bbox_inches="tight")
plt.close()

# %%
# pareto front points
pf1 = [
    [
      117.83244323730469,
      121.94172668457031
    ],
    [
      126.59394836425781,
      0.21161861717700958
    ],
    [
      129.17929077148438,
      -1.8089897632598877
    ],
    [
      131.2404022216797,
      -10.115581512451172
    ],
    [
      131.97036743164062,
      -10.251462936401367
    ],
    [
      130.8586883544922,
      -8.588836669921875
    ],
    [
      130.73550415039062,
      -8.300444602966309
    ],
    [
      129.7945556640625,
      -5.212832450866699
    ],
    [
      131.98097229003906,
      -13.097819328308105
    ],
    [
      131.08087158203125,
      -9.407559394836426
    ],
    [
      132.6107177734375,
      -14.663148880004883
    ],
    [
      132.23922729492188,
      -13.369982719421387
    ],
    [
      130.93972778320312,
      -9.222536087036133
    ],
    [
      132.8013916015625,
      -14.800176620483398
    ]
]
pf2 = [
    [
      58.68064498901367,
      46.25283432006836
    ],
    [
      88.71468353271484,
      36.36406707763672
    ],
    [
      85.6006088256836,
      37.29482650756836
    ],
    [
      85.77012634277344,
      36.49196243286133
    ],
    [
      79.05583190917969,
      40.017181396484375
    ],
    [
      96.59089660644531,
      34.59724044799805
    ],
    [
      86.29186248779297,
      36.420589447021484
    ],
    [
      96.21684265136719,
      35.00899887084961
    ],
    [
      99.53721618652344,
      32.03858184814453
    ],
    [
      105.1343994140625,
      29.61764907836914
    ],
    [
      89.15898132324219,
      35.435787200927734
    ],
    [
      85.27226257324219,
      37.954734802246094
    ],
    [
      97.73307800292969,
      34.037353515625
    ],
    [
      101.48429870605469,
      31.794347763061523
    ],
    [
      99.48339080810547,
      33.01521682739258
    ],
    [
      112.7536392211914,
      23.533279418945312
    ],
    [
      112.33988952636719,
      23.944751739501953
    ],
    [
      108.71712493896484,
      27.543914794921875
    ],
    [
      109.60980224609375,
      25.454994201660156
    ],
    [
      123.7266845703125,
      11.209917068481445
    ],
    [
      118.54457092285156,
      19.86911964416504
    ],
    [
      121.09004211425781,
      15.690202713012695
    ],
    [
      115.58807373046875,
      22.716880798339844
    ],
    [
      124.46351623535156,
      8.710269927978516
    ],
    [
      124.1829605102539,
      10.751917839050293
    ],
    [
      122.64820861816406,
      12.816778182983398
    ],
    [
      122.1480484008789,
      13.08155632019043
    ],
    [
      124.07391357421875,
      10.90381908416748
    ],
    [
      118.77128601074219,
      17.614673614501953
    ],
    [
      111.8474349975586,
      24.571491241455078
    ],
    [
      104.19564056396484,
      30.40397071838379
    ],
    [
      121.3315658569336,
      13.727200508117676
    ],
    [
      117.11509704589844,
      20.843143463134766
    ],
    [
      124.23908996582031,
      9.378381729125977
    ]
]

# %%
# x and y lists
pf1_x, pf1_y = zip(*pf1)
pf2_x, pf2_y = zip(*pf2)

plt.figure(figsize=(8, 6))
plt.scatter(pf1_x, pf1_y, label="Run A", color='#A12864', marker='o', s=60)
plt.scatter(pf2_x, pf2_y, label="Run B", color='#C565C7', marker='o', s=60)

plt.xlabel("Objective 1", fontsize=17)
plt.ylabel("Objective 2", fontsize=17)
# plt.title("Pareto Front - Hopper")
plt.legend(fontsize=12)
plt.grid(True)
plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/limitation-pf.pdf", format="pdf", bbox_inches="tight")
plt.close()

# %%
plt.rcParams["font.size"] = 12
plt.rcParams["font.family"] = "Times New Roman"

# %%
import numpy as np

# Generate sample data for the Pareto front
pareto_x = np.linspace(0.1, 1, 10)  # Objective 1 values
pareto_y = 1 - pareto_x**2  # Objective 2 values (convex Pareto front)

# Generate dominated points below the Pareto front
dominated_x = np.random.uniform(0.1, 1, 20)
dominated_y = np.random.uniform(0, 0.9 * (1 - dominated_x**2), 20)

# Create the plot
plt.figure(figsize=(6, 6))
plt.scatter(dominated_x, dominated_y, color='gray', edgecolors='black', label='Dominated Solutions', alpha=0.6)
plt.plot(pareto_x, pareto_y, marker='o', color='black', markersize=6, label='Pareto Front')

# plt.rcParams["font.size"] = 12
plt.xlabel("Objective 1", fontdict={"fontsize": 18})
plt.ylabel("Objective 2", fontdict={"fontsize": 18})

# plt.title("Pareto Front Visualization")
plt.legend(prop={"size": 16})

plt.grid(True)
#plt.show()
plt.savefig("/Users/clarissakuemhof/Library/Mobile Documents/com~apple~CloudDocs/LMU/5. Semester/Masterarbeit/plots-thesis/pareto-front.pdf", format="pdf", bbox_inches="tight")
plt.close()
